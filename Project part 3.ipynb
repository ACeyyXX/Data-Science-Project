# %% [markdown]
# Data Science Project (Part 2)
#
# Introduction:
# Protected areas slow declines unevenly across the tetrapod tree of life
# -	https://www.nature.com/articles/s41586-023-06562-y#data-availability
# -	I found this article in the NATURE journal. In this article, the authors have provided with the link to the excel spreadsheets in the ‘data availability’ section of the article.
# -	This research article is about evaluating the effectiveness of Protected Areas (PAs) in conserving terrestrial vertebrate biodiversity. The study aims to determine whether PAs are effective in slowing down the decline of terrestrial vertebrate populations across different taxonomic groups (tetrapods).
#
#
# Section 1:
# •	Describe the Data:
#     o	Observations: Each row in the dataset represents a unique combination of a species and its specific location, totaling 930 observations.
#     o	These observations encompass diverse taxonomic groups, including mammals, birds, amphibians, and reptiles, with a global distribution across various biomes and realms.
#
# o	Features: The dataset includes a rich variety of features organized into several categories:
#     o	Species Information:
#         	Species name.
#         	Class.
#         	IUCN conservation status, indicating the threat level.
#     o	Geographic Information:
#         	Coordinates (latitude and longitude), Realm.
#     o	Environmental Variables:
#         	Elevation, mean annual temperature, and annual precipitation provide data on habitat conditions.
#     o	Human Impact Factors:
#         	Population density, GDP, and governance index, which capture socio-economic contexts affecting species.
#     o	Protected Area Information:
#         	Information on protected area status, year of protection, and IUCN category.
#     o	Habitat Characteristics:
#         	Proportions of land cover types, such as forest and grassland cover, provide insights into habitat features.
# o	Climate Change Indicators:
# 	Data on climate velocity, climate trends, and climate distance illustrate climate change effects over time.
# o	Derived/Calculated Features:
# 	Includes transformed or standardized variables, such as log-transformed population and GDP, binary indicators, and standardized protected area age.
#
# o	The dataset also incorporates external data on geographical, climatic, and socio-economic aspects, enabling a comprehensive ecological analysis. This diverse data allows for assessing multiple interacting factors that might impact species' conservation and survival in protected areas.
#
# •	Research Questions:
# 	The main question likely investigates whether protected areas (PAs) are effective in slowing biodiversity declines across various taxonomic groups, specifically in tetrapods. The hypothesis could be that species within protected areas experience slower rates of decline than those outside, potentially due to controlled human impact and conservation efforts within these protected zones. The dataset's combination of species-specific biological, geographic, and socio-economic data makes it suitable for evaluating the impact of protected areas across multiple dimensions, allowing for a nuanced analysis of PA effectiveness on biodiversity.
# 	An alternative question could explore how climate change impacts differ among species within protected areas versus those outside. The climate change indicators in the dataset (e.g., climate velocity, climate trend) are directly relevant for investigating how protected areas might buffer species from climate-induced habitat changes, providing a useful basis for studying this relationship.
#
#
# Section 2:
# Figure 1 -  ![image.png](attachment:d8f6b755-72d7-4ec0-9f95-c3789278feaa.png)
# Locations of populations being studied are marked across the world, with circles representing populations inside protected areas and triangles for populations outside.
# Each data point on the map corresponds to a unique location of population observations for four vertebrate classes: amphibians, reptiles, birds, and mammals. Different colors denote each vertebrate class: yellow for amphibians, blue for reptiles, purple for birds, and black for mammals.
# The figure illustrates the geographical distribution of population studies for different vertebrate classes and their locations relative to protected areas. By showing a mix of both protected (circles) and unprotected (triangles) locations, the figure highlights the global and ecological scope of the data, emphasizing the diversity of environments and protection statuses covered in the study.
# This visualization supports the study’s scope by confirming that the population data covers a wide range of habitats and vertebrate classes across various global regions. It suggests that the conclusions drawn from the study may be broadly applicable across different taxa and environments. Additionally, the balance of protected versus unprotected sites allows for a comparative analysis, showing potential regional variations in the effectiveness of protected areas.
#
#
# Figure 2 – ![image.png](attachment:14d3efd0-228e-46b9-923f-3e8df80f2280.png)
# The y-axis lists various factors that could affect population trends, including specific classes (amphibians, reptiles, birds, mammals), protected area status (PA), and additional environmental, socio-economic, and human impact variables like climate change, land cover change, governance, and GDP.
# The x-axis represents the effect on population trends, with negative values indicating a decline in population trends and positive values suggesting an improvement or stability in population trends.
# Data points are plotted along each factor on the y-axis, with confidence intervals showing the variability in the effect of each factor on population trends. Notably, amphibians and birds show higher overall trends in protected areas (highlighted by the color-coded points), while other factors like climate change and governance also exhibit varying effects.
# This figure is critical in demonstrating the relative impact of protected areas and various external factors on population trends across different taxonomic classes. By showing that population trends are generally more positive within protected areas, especially for amphibians and birds, the figure supports the hypothesis that protected areas benefit biodiversity. Additionally, it contextualizes the influence of other factors, such as climate change and governance, which might mitigate or exacerbate population trends.
# The figure reveals that protected areas tend to have a positive impact on population trends, particularly for amphibians and birds. It also indicates that factors like governance and climate change significantly influence population trends, suggesting that the effectiveness of protected areas may be modulated by broader environmental and socio-political contexts. This reinforces the importance of targeted conservation efforts and adaptive management to account for these additional influences on biodiversity.
#
#
# Proposed Figure:![image.png](attachment:c22b297b-205a-4125-b9da-54443ec4fabf.png)
# Comparison of Population Decline Rates Inside and Outside Protected Areas by Biome
# o	X-axis: Different biomes (e.g., Tropical Rainforests, Temperate Forests, Grasslands, Deserts).
# o	Y-axis: Average population decline rate, with separate bars for populations inside and outside protected areas.
# o	Colors: Two colors for each biome, one for protected and one for unprotected, showing any differences in population decline rates across biomes.
# o	This figure would help determine whether the effectiveness of protected areas varies by biome. By comparing average decline rates across different biomes, the figure could highlight specific biomes where protected areas are more or less effective. This would be useful in identifying conservation priorities based on biome-specific challenges, providing insights into which ecosystems might need more focused protection strategies.
#
#
# Section 3:
# Each file in this dataset is structured to align with the 930 unique species-location observations. The files are likely in CSV format, with columns separated by commas, and missing values denoted as "NA". This standardized format facilitates easy integration and analysis across different data dimensions, allowing for a comprehensive assessment of how protected areas influence population trends while accounting for environmental, socio-economic, and climate-related variables.
# The data files’ structure and format allow for seamless merging of information, making it possible to investigate relationships between species population trends and factors such as human impact, environmental conditions, and climate change across protected and unprotected areas.

# %% [markdown]
# Comments for Part 2

# %% [markdown]
# **Part 3**

# %% [markdown]
# Below is the link to the dataset/ the csv file i obtained from the research paper.

# %% [markdown]
# https://doi.org/10.6084/m9.figshare.14821644.

# %% [markdown]
# I downloaded the dataset from the given link and then following the path given below I used the specific data/ csv file for this project.

# %% [markdown]
# C:\Users\Admin\Downloads\Data_and_code\Data_and_code\Data\ad-hoc_analyses\site_matched_pa_vars

# %%
import pandas as pd

# Load data
data = pd.read_csv('site_matched_pa_vars.csv')
dataset = data.set_index("siteXspp")

dataset
# Out:
#                                                         site         pa  \
# siteXspp
# Abrothrix_olivaceus_-31.5_-71.1                  -31.5_-71.1  Protected
# Accipiter_gentilis_52.16667_8.41667         52.16667_8.41667  Protected
# Accipiter_nisus_51.29167_-0.38361          51.29167_-0.38361  Protected
# Acris_gryllus_29.68333_-82                      29.68333_-82  Protected
# Acrocephalus_arundinaceus_42.2_3.11667          42.2_3.11667  Protected
# ...                                                      ...        ...
# Xenops_rutilans_-22.33333_-47.5              -22.33333_-47.5  Protected
# Zamenis_longissimus_46.11667_-0.41667      46.11667_-0.41667  Protected
# Zapornia_parva_43.83139_10.33278           43.83139_10.33278  Protected
# Zonotrichia_capensis_-22.33333_-47.5         -22.33333_-47.5  Protected
# Zosterops_japonicus_19.46583_-155.37139  19.46583_-155.37139  Protected
#
#                                             class           iucn        realm  \
# siteXspp
# ...

# %%
# Display the first few rows
dataset.head()
# Out:
#                                                      site         pa  \
# siteXspp
# Abrothrix_olivaceus_-31.5_-71.1               -31.5_-71.1  Protected
# Accipiter_gentilis_52.16667_8.41667      52.16667_8.41667  Protected
# Accipiter_nisus_51.29167_-0.38361       51.29167_-0.38361  Protected
# Acris_gryllus_29.68333_-82                   29.68333_-82  Protected
# Acrocephalus_arundinaceus_42.2_3.11667       42.2_3.11667  Protected
#
#                                            class           iucn        realm  \
# siteXspp
# Abrothrix_olivaceus_-31.5_-71.1         Mammalia  Least Concern  Neotropical
# Accipiter_gentilis_52.16667_8.41667         Aves  Least Concern   Palearctic
# Accipiter_nisus_51.29167_-0.38361           Aves  Least Concern   Palearctic
# Acris_gryllus_29.68333_-82              Amphibia  Least Concern     Nearctic
# Acrocephalus_arundinaceus_42.2_3.11667      Aves  Least Concern   Palearctic
#
# ...

# %%
# Cleaning: Drop rows with missing values
cleaned_dataset = dataset.dropna()
cleaned_dataset
# Out:
#                                                         site         pa  \
# siteXspp
# Abrothrix_olivaceus_-31.5_-71.1                  -31.5_-71.1  Protected
# Accipiter_gentilis_52.16667_8.41667         52.16667_8.41667  Protected
# Accipiter_nisus_51.29167_-0.38361          51.29167_-0.38361  Protected
# Acris_gryllus_29.68333_-82                      29.68333_-82  Protected
# Acrocephalus_arundinaceus_42.2_3.11667          42.2_3.11667  Protected
# ...                                                      ...        ...
# Xenops_rutilans_-22.33333_-47.5              -22.33333_-47.5  Protected
# Zamenis_longissimus_46.11667_-0.41667      46.11667_-0.41667  Protected
# Zapornia_parva_43.83139_10.33278           43.83139_10.33278  Protected
# Zonotrichia_capensis_-22.33333_-47.5         -22.33333_-47.5  Protected
# Zosterops_japonicus_19.46583_-155.37139  19.46583_-155.37139  Protected
#
#                                             class           iucn        realm  \
# siteXspp
# ...

# %%
# Display cleaned data
cleaned_dataset.head()
# Out:
#                                                      site         pa  \
# siteXspp
# Abrothrix_olivaceus_-31.5_-71.1               -31.5_-71.1  Protected
# Accipiter_gentilis_52.16667_8.41667      52.16667_8.41667  Protected
# Accipiter_nisus_51.29167_-0.38361       51.29167_-0.38361  Protected
# Acris_gryllus_29.68333_-82                   29.68333_-82  Protected
# Acrocephalus_arundinaceus_42.2_3.11667       42.2_3.11667  Protected
#
#                                            class           iucn        realm  \
# siteXspp
# Abrothrix_olivaceus_-31.5_-71.1         Mammalia  Least Concern  Neotropical
# Accipiter_gentilis_52.16667_8.41667         Aves  Least Concern   Palearctic
# Accipiter_nisus_51.29167_-0.38361           Aves  Least Concern   Palearctic
# Acris_gryllus_29.68333_-82              Amphibia  Least Concern     Nearctic
# Acrocephalus_arundinaceus_42.2_3.11667      Aves  Least Concern   Palearctic
#
# ...

# %% [markdown]
# What this code did was uploaded and opened a dataframe which was in the same directory as this notebook.
# Then cleaned the dataset which means that the cells showing values like NaN were removed from the dataframe and .head() gives us the first 5 observations/rows of the dataframe.

# %%
# Shape of the dataset
cleaned_dataset.shape
# Out:
# (898, 65)

# %% [markdown]
# This tells us that the dataframe consists of 898 rows/observations and 65 columns/features.

# %% [markdown]
# The 2 features that I choose for this project are
# 1. class
# 2. realm

# %% [markdown]
# For the first feature there are 4 different values for the feature.
# The most visible is Aves, so I am guessing there are majority of observations having Aves as their value for the class feature

# %%
cleaned_dataset['class'].describe()
# Out:
# count      898
# unique       4
# top       Aves
# freq       532
# Name: class, dtype: object

# %% [markdown]
# Well to what I guessed Aves is the top value for most of the observations (almost 70% of the observations)

# %% [markdown]
# For the second feature, there seem to be around 6-7 different values.
# The most visible was maybe Palearctic or Nearctic

# %%
cleaned_dataset['realm'].describe()
# Out:
# count            898
# unique             7
# top       Palearctic
# freq             462
# Name: realm, dtype: object

# %% [markdown]
# As guessed, There are 7 different values for the feature 'realm' wherein, Palearctic is the top value for this feature.

# %% [markdown]
# **VISUALIZATIONS**

# %%
import seaborn as sns
sns.set_theme()

# %% [markdown]
# For the first visualization I chose a histogram for the first feature i.e. 'class'
# The histogram shows the frequency distribution of the class feature.
# This gives insight into how often each class appears in the dataset.

# %%
sns.displot(data=cleaned_dataset, x='class', bins=20, kde=True)

# %% [markdown]
# For the second visualization I chose a bar graph for the second feature i.e. 'realm'.
# This bar graph is realm against iucn. A barplot is appropriate here because it aggregates and shows the mean values of the numerical feature iucn for each category in realm.

# %%
sns.barplot(data=cleaned_dataset, x='realm', y='iucn')
# Out:
# <Axes: xlabel='realm', ylabel='iucn'>

# %% [markdown]
# This visualization highlights trends or anomalies in iucn scores across realms.
